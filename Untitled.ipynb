# %%
from azureml.core import Workspace, Dataset

# %%
ws = Workspace.from_config()

# %%
dset = Dataset.get_by_name(ws, 'target')
dset
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'datadrift-data/2019/**/data.parquet')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ReadParquetFile",
#     "DropColumns"
#   ],
#   "registration": {
#     "name": "target",
#     "version": 2,
#     "workspace": "Workspace.create(name='Azure-ML', subscription_id='60582a10-b9fd-49f1-a546-c4194134bba8', resource_group='copetersRG')"
#   }
# }

# %%
dset_id = dset.id
dset_id
# Out:
# '8f4f67e9-6a92-4ad8-8b62-ff422cbf9e3a'

# %%
dset2 = Dataset.get_by_id(ws, dset_id)
dset2
# Out:
# {
#   "source": [
#     "('workspaceblobstore', 'datadrift-data/2019/**/data.parquet')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ReadParquetFile",
#     "DropColumns"
#   ],
#   "registration": {
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='Azure-ML', subscription_id='60582a10-b9fd-49f1-a546-c4194134bba8', resource_group='copetersRG')"
#   }
# }

# %%
dset2.id
# Out:
# '8f4f67e9-6a92-4ad8-8b62-ff422cbf9e3a'

# %%
print(dset2.version)
# Out:
# None

# %%
dset.version
# Out:
# 2

# %%
print(dset2.name)
# Out:
# None
