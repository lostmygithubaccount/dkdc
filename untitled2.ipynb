# %%
import azureml.core 

azureml.core.VERSION
# Out:
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (azureml-dataprep 2.3.0 (/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages), Requirement.parse(&#39;azureml-dataprep&lt;2.3.0a,&gt;=2.2.0a&#39;), {&#39;azureml-dataset-runtime&#39;}).
# &#39;1.15.0&#39;

# %%
import azureml.dataprep 

azureml.dataprep.__version__
# Out:
# &#39;2.3.0&#39;

# %%
from torchvision import datasets 
from azureml.core import Dataset, Workspace

ws = Workspace.from_config()
ws
# Out:
# Workspace.create(name=&#39;AzureML&#39;, subscription_id=&#39;6560575d-fa06-4e7d-95fb-f962e74efd7a&#39;, resource_group=&#39;cody-eastus-rg&#39;)

# %%
datasets.CIFAR10(".", download=True)
# Out:
# Files already downloaded and verified
# Dataset CIFAR10
#     Number of datapoints: 50000
#     Root location: .
#     Split: Train

# %%
# %%time
ws.get_default_datastore().upload("cifar-10-batches-py", "test/cifar")
# Out:
# /dkdc/lib/python3.8/site-packages/ipykernel/kernelbase.py&quot;, line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 209, in wrapper
#     yielded = next(result)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/kernelbase.py&quot;, line 543, in execute_request
#     self.do_execute(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 209, in wrapper
#     yielded = next(result)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/ipkernel.py&quot;, line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/zmqshell.py&quot;, line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2876, in run_cell
#     result = self._run_cell(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2922, in _run_cell
#     return runner(coro)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/async_helpers.py&quot;, line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3145, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File &quot;&lt;ipython-input-6-a53962a17baf&gt;&quot;, line 1, in &lt;module&gt;
#     get_ipython().run_cell_magic(&#39;time&#39;, &#39;&#39;, &#39;ws.get_default_datastore().upload(&quot;cifar-10-batches-py&quot;, &quot;test/cifar&quot;)\n&#39;)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2381, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File &quot;&lt;decorator-gen-54&gt;&quot;, line 2, in time
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/magic.py&quot;, line 187, in &lt;lambda&gt;
#     call = lambda f, *a, **k: f(*a, **k)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/magics/execution.py&quot;, line 1313, in time
#     out = eval(code, glob, local_ns)
#   File &quot;&lt;timed eval&gt;&quot;, line 1, in &lt;module&gt;
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 730, in upload
#     count = self._start_upload_task(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 320, in _start_upload_task
#     tq.add_task(async_task)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 53, in __exit__
#     self.flush(self.identity)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 116, in flush
#     self._results.extend((task.wait(awaiter_name=self.identity) for task in completed_tasks))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 116, in &lt;genexpr&gt;
#     self._results.extend((task.wait(awaiter_name=self.identity) for task in completed_tasks))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/async_task.py&quot;, line 59, in wait
#     res = self._handler(self._future, self._logger)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 339, in handler
#     exception_handler(e, logger)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 303, in exception_handler
#     logger.error(&quot;Upload failed, please make sure target_path does not start with invalid characters.&quot;, e)
# Message: &#39;Upload failed, please make sure target_path does not start with invalid characters.&#39;
# Arguments: (AzureException(MaxRetryError(&quot;HTTPSConnectionPool(host=&#39;azuremlstoragef92a69eef1.blob.core.windows.net&#39;, port=443): Max retries exceeded with url: /azureml-blobstore-b0304e68-b406-492f-90b6-ae4897ecdb33/test/cifar/data_batch_5 (Caused by ProtocolError(&#39;Connection aborted.&#39;, timeout(&#39;The write operation timed out&#39;)))&quot;)),)
# Uploading cifar-10-batches-py/test_batch
# Uploaded 1 files
# CPU times: user 4.9 s, sys: 5.39 s, total: 10.3 s
# Wall time: 6min 40s
# --- Logging error ---
# Traceback (most recent call last):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 670, in urlopen
#     httplib_response = self._make_request(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 392, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/http/client.py&quot;, line 1255, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/http/client.py&quot;, line 1301, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/http/client.py&quot;, line 1250, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/http/client.py&quot;, line 1049, in _send_output
#     self.send(chunk)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/http/client.py&quot;, line 971, in send
#     self.sock.sendall(data)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/ssl.py&quot;, line 1204, in sendall
#     v = self.send(byte_view[count:])
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/ssl.py&quot;, line 1173, in send
#     return self._sslobj.write(data)
# socket.timeout: The write operation timed out
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/requests/adapters.py&quot;, line 439, in send
#     resp = conn.urlopen(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 754, in urlopen
#     return self.urlopen(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 754, in urlopen
#     return self.urlopen(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 754, in urlopen
#     return self.urlopen(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/connectionpool.py&quot;, line 726, in urlopen
#     retries = retries.increment(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/urllib3/util/retry.py&quot;, line 439, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPSConnectionPool(host=&#39;azuremlstoragef92a69eef1.blob.core.windows.net&#39;, port=443): Max retries exceeded with url: /azureml-blobstore-b0304e68-b406-492f-90b6-ae4897ecdb33/test/cifar/test_batch (Caused by ProtocolError(&#39;Connection aborted.&#39;, timeout(&#39;The write operation timed out&#39;)))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/common/storageclient.py&quot;, line 269, in _perform_request
#     response = self._httpclient.perform_request(request)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/common/_http/httpclient.py&quot;, line 86, in perform_request
#     response = self.session.request(request.method,
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/requests/sessions.py&quot;, line 530, in request
#     resp = self.send(prep, **send_kwargs)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/requests/sessions.py&quot;, line 643, in send
#     r = adapter.send(request, **kwargs)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/requests/adapters.py&quot;, line 516, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPSConnectionPool(host=&#39;azuremlstoragef92a69eef1.blob.core.windows.net&#39;, port=443): Max retries exceeded with url: /azureml-blobstore-b0304e68-b406-492f-90b6-ae4897ecdb33/test/cifar/test_batch (Caused by ProtocolError(&#39;Connection aborted.&#39;, timeout(&#39;The write operation timed out&#39;)))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 331, in handler
#     result = future.result()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/concurrent/futures/_base.py&quot;, line 432, in result
#     return self.__get_result()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/concurrent/futures/_base.py&quot;, line 388, in __get_result
#     raise self._exception
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/concurrent/futures/thread.py&quot;, line 57, in run
#     result = self.fn(*self.args, **self.kwargs)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 735, in &lt;lambda&gt;
#     lambda target, source: lambda: self.blob_service.create_blob_from_path(self.container_name, target, source)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/blob/blockblobservice.py&quot;, line 448, in create_blob_from_path
#     return self.create_blob_from_stream(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/blob/blockblobservice.py&quot;, line 570, in create_blob_from_stream
#     resp = self._put_blob(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/blob/blockblobservice.py&quot;, line 971, in _put_blob
#     return self._perform_request(request, _parse_base_properties)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/common/storageclient.py&quot;, line 381, in _perform_request
#     raise ex
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_vendor/azure_storage/common/storageclient.py&quot;, line 311, in _perform_request
#     raise AzureException(ex.args[0])
# azure.common.AzureException: HTTPSConnectionPool(host=&#39;azuremlstoragef92a69eef1.blob.core.windows.net&#39;, port=443): Max retries exceeded with url: /azureml-blobstore-b0304e68-b406-492f-90b6-ae4897ecdb33/test/cifar/test_batch (Caused by ProtocolError(&#39;Connection aborted.&#39;, timeout(&#39;The write operation timed out&#39;)))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/logging/__init__.py&quot;, line 1081, in emit
#     msg = self.format(record)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/logging/__init__.py&quot;, line 925, in format
#     return fmt.format(record)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/logging/__init__.py&quot;, line 664, in format
#     record.message = record.getMessage()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/logging/__init__.py&quot;, line 369, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/runpy.py&quot;, line 194, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/runpy.py&quot;, line 87, in _run_code
#     exec(code, run_globals)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel_launcher.py&quot;, line 16, in &lt;module&gt;
#     app.launch_new_instance()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/traitlets/config/application.py&quot;, line 837, in launch_instance
#     app.start()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/kernelapp.py&quot;, line 612, in start
#     self.io_loop.start()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/platform/asyncio.py&quot;, line 149, in start
#     self.asyncio_loop.run_forever()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/asyncio/base_events.py&quot;, line 570, in run_forever
#     self._run_once()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/asyncio/base_events.py&quot;, line 1859, in _run_once
#     handle._run()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/asyncio/events.py&quot;, line 81, in _run
#     self._context.run(self._callback, *self._args)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/ioloop.py&quot;, line 690, in &lt;lambda&gt;
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/ioloop.py&quot;, line 743, in _run_callback
#     ret = callback()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 787, in inner
#     self.run()
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 748, in run
#     yielded = self.gen.send(value)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/kernelbase.py&quot;, line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 209, in wrapper
#     yielded = next(result)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/kernelbase.py&quot;, line 268, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 209, in wrapper
#     yielded = next(result)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/kernelbase.py&quot;, line 543, in execute_request
#     self.do_execute(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/tornado/gen.py&quot;, line 209, in wrapper
#     yielded = next(result)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/ipkernel.py&quot;, line 306, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/ipykernel/zmqshell.py&quot;, line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2876, in run_cell
#     result = self._run_cell(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2922, in _run_cell
#     return runner(coro)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/async_helpers.py&quot;, line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3145, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3337, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 3417, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File &quot;&lt;ipython-input-6-a53962a17baf&gt;&quot;, line 1, in &lt;module&gt;
#     get_ipython().run_cell_magic(&#39;time&#39;, &#39;&#39;, &#39;ws.get_default_datastore().upload(&quot;cifar-10-batches-py&quot;, &quot;test/cifar&quot;)\n&#39;)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/interactiveshell.py&quot;, line 2381, in run_cell_magic
#     result = fn(*args, **kwargs)
#   File &quot;&lt;decorator-gen-54&gt;&quot;, line 2, in time
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/magic.py&quot;, line 187, in &lt;lambda&gt;
#     call = lambda f, *a, **k: f(*a, **k)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/IPython/core/magics/execution.py&quot;, line 1313, in time
#     out = eval(code, glob, local_ns)
#   File &quot;&lt;timed eval&gt;&quot;, line 1, in &lt;module&gt;
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 730, in upload
#     count = self._start_upload_task(
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 320, in _start_upload_task
#     tq.add_task(async_task)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 53, in __exit__
#     self.flush(self.identity)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 116, in flush
#     self._results.extend((task.wait(awaiter_name=self.identity) for task in completed_tasks))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/task_queue.py&quot;, line 116, in &lt;genexpr&gt;
#     self._results.extend((task.wait(awaiter_name=self.identity) for task in completed_tasks))
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/_common/async_utils/async_task.py&quot;, line 59, in wait
#     res = self._handler(self._future, self._logger)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 339, in handler
#     exception_handler(e, logger)
#   File &quot;/Users/cody/miniconda3/envs/dkdc/lib/python3.8/site-packages/azureml/data/azure_storage_datastore.py&quot;, line 303, in exception_handler
#     logger.error(&quot;Upload failed, please make sure target_path does not start with invalid characters.&quot;, e)
# Message: &#39;Upload failed, please make sure target_path does not start with invalid characters.&#39;
# Arguments: (AzureException(MaxRetryError(&quot;HTTPSConnectionPool(host=&#39;azuremlstoragef92a69eef1.blob.core.windows.net&#39;, port=443): Max retries exceeded with url: /azureml-blobstore-b0304e68-b406-492f-90b6-ae4897ecdb33/test/cifar/test_batch (Caused by ProtocolError(&#39;Connection aborted.&#39;, timeout(&#39;The write operation timed out&#39;)))&quot;)),)
# $AZUREML_DATAREFERENCE_7ef239e6a6e5470eace282ff1d99c65f

# %%
# %%time
Dataset.File.upload_directory("cifar-10-batches-py", (ws.get_default_datastore(), "test/cifar"))

# %%
# !pip freeze
