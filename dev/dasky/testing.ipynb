# %%
import warnings

warnings.simplefilter('ignore')

# %%
import dask.dataframe as dd
from dask.distributed import Client

# %%
c = Client()
c.restart()
c
# Out:
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# distributed.comm.tcp - WARNING - Could not set timeout on TCP stream: [Errno 92] Protocol not available
# ...

# %%
from azureml.core import Workspace, Dataset

# %%
ws = Workspace.from_config()
ws
# Out:
# Workspace.create(name='dasky-AML', subscription_id='6560575d-fa06-4e7d-95fb-f962e74efd7a', resource_group='copetersRG')

# %%
dstore = ws.get_default_datastore()
#dstore.upload('data/weather', 'testing/dask-parquet-test')

# %%
dset = Dataset.File.from_files(dstore.path('testing/dask-parquet-test/*.parquet'))

# %%
dset = dset.register(ws, 'florida-files')

# %%
df = dd.read_parquet(dstore.path('testing/dask-parquet-test/*.parquet'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-756e972f56ea> in <module>
# ----> 1 df = dd.read_parquet(dstore.path('testing/dask-parquet-test/*.parquet'))
#
# ~/miniconda3/envs/dasky/lib/python3.6/site-packages/dask/dataframe/io/parquet/core.py in read_parquet(path, columns, filters, categories, index, storage_options, engine, gather_statistics, split_row_groups, chunksize, **kwargs)
#     203     if hasattr(path, "name"):
#     204         path = stringify_path(path)
# --> 205     fs, _, paths = get_fs_token_paths(path, mode="rb", storage_options=storage_options)
#     206
#     207     paths = sorted(paths, key=natural_sort_key)  # numeric rather than glob ordering
#
# ~/miniconda3/envs/dasky/lib/python3.6/site-packages/fsspec/core.py in get_fs_token_paths(urlpath, mode, num, name_function, storage_options, protocol)
#     406
#     407     else:
# ...
