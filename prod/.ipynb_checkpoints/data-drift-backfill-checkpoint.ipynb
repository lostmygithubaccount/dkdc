# %%
from azureml.core import Workspace, Dataset

from azureml.datadrift import DataDriftDetector

from datetime import datetime, timedelta

# %%
ws     = Workspace.from_config()
dstore = ws.get_default_datastore()

# %%
dstore.upload('data', 'florida-weather-2019', overwrite=True)
# Out:
# Uploading an estimated of 10 files
# Uploading data/2019/01/data.parquet
# Uploading data/2019/02/data.parquet
# Uploading data/2019/03/data.parquet
# Uploading data/2019/04/data.parquet
# Uploading data/2019/05/data.parquet
# Uploading data/2019/06/data.parquet
# Uploading data/2019/07/data.parquet
# Uploading data/2019/08/data.parquet
# Uploading data/2019/09/data.parquet
# Uploading data/2019/10/data.parquet
# Uploaded data/2019/10/data.parquet, 1 files out of an estimated total of 10
# Uploaded data/2019/09/data.parquet, 2 files out of an estimated total of 10
# Uploaded data/2019/05/data.parquet, 3 files out of an estimated total of 10
# Uploaded data/2019/07/data.parquet, 4 files out of an estimated total of 10
# Uploaded data/2019/03/data.parquet, 5 files out of an estimated total of 10
# Uploaded data/2019/01/data.parquet, 6 files out of an estimated total of 10
# Uploaded data/2019/02/data.parquet, 7 files out of an estimated total of 10
# ...

# %%
dset   = Dataset.Tabular.from_parquet_files(dstore.path('florida-weather-2019/**/data.parquet'))

# %%
target = dset.with_timestamp_columns('datetime')
target = target.register(ws, 'target')

# %%
target = Dataset.get_by_name(ws, 'target')

# %%
baseline = target.time_before(datetime(2019, 2, 1))

# %%
features = ['latitude', 'longitude', 'elevation', 'windAngle', 'windSpeed', 'temperature', 'snowDepth', 'stationName', 'countryOrRegion']

# %%
monitor = DataDriftDetector.create_from_datasets(ws, 'drift_monitor', baseline, target, 
                                                      compute_target_name='cpu-cluster', 
                                                      frequency='Week', 
                                                      feature_list=None, 
                                                      drift_threshold=None, 
                                                      latency=0)
# Out:
# 2019-10-07 18:12:36,734 - azureml.datadrift._logging._telemetry_logger.datadriftdetector.create_from_datasets - ERROR - DataDriftDetector with name drift_monitor already exists. Please use get_by_name() to retrieve it - activity_id:3625ca4e-8c29-4176-8a23-9cc74f94ab24 activity_name:datadriftdetector.create_from_datasets activity_type:InternalCall workspace_name:DataDrift-Prod-EUAP baseline_dataset:TabularDataset
# {
#   "source": [
#     "('workspaceblobstore', 'florida-weather-2019/**/data.parquet')"
#   ],
#   "definition": [
#     "GetDatastoreFiles",
#     "ReadParquetFile",
#     "DropColumns",
#     "ExpressionFilter"
#   ],
#   "registration": {
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='DataDrift-Prod-EUAP', subscription_id='60582a10-b9fd-49f1-a546-c4194134bba8', resource_group='copetersRG')"
#   }
# } target_dataset:TabularDataset
# {
#   "source": [
#     "('workspaceblobstore', 'florida-weather-2019/**/data.parquet')"
#   ],
# ...

# %%
monitor = DataDriftDetector.get_by_name(ws, 'drift_monitor')

monitor.update(feature_list=None)
# Out:
# {'_workspace': Workspace.create(name='DataDrift-Prod-EUAP', subscription_id='60582a10-b9fd-49f1-a546-c4194134bba8', resource_group='copetersRG'), '_frequency': 'Week', '_schedule_start': None, '_schedule_id': None, '_interval': 1, '_state': 'Disabled', '_alert_config': None, '_type': 'DatasetBased', '_id': '8a90888d-5860-41b2-9b65-3d2b354328ee', '_model_name': None, '_model_version': 0, '_services': None, '_compute_target_name': 'cpu-cluster', '_drift_threshold': 0.2, '_baseline_dataset_id': '3521f159-898a-47bf-afbb-0e7479d043c2', '_target_dataset_id': '0392292f-ca55-4fcf-ada5-655c34f6da96', '_feature_list': None, '_latency': 0, '_name': 'drift_monitor', '_client': <azureml.datadrift._restclient.datadrift_client.DataDriftClient object at 0x7fd840338590>, '_logger': <_TelemetryLoggerContextAdapter azureml.datadrift._logging._telemetry_logger.azureml.datadrift.datadriftdetector (DEBUG)>}

# %%
backfill1 = monitor.backfill(datetime(2019, 1, 1), datetime(2019, 5, 1), feature_list=features)
backfill1
# Out:
# Run(Experiment: 8a90888d-5860-41b2-9b65-3d2b354328ee,
# Id: 8a90888d-5860-41b2-9b65-3d2b354328ee_1570497320552,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
backfill2 = monitor.backfill(datetime(2019, 5, 1), datetime.today(), feature_list=features)
backfill2
# Out:
# Run(Experiment: 8a90888d-5860-41b2-9b65-3d2b354328ee,
# Id: 8a90888d-5860-41b2-9b65-3d2b354328ee_1570497354069,
# Type: azureml.scriptrun,
# Status: Starting)

# %%
help(DataDriftDetector)
# Out:
# Help on class DataDriftDetector in module azureml.datadrift.datadriftdetector:
#
# class DataDriftDetector(builtins.object)
#  |  DataDriftDetector(workspace, model_name, model_version)
#  |
#  |  Class for AzureML DataDriftDetector.
#  |
#  |  DataDriftDetector class provides set of convenient APIs to identify any drifting between given training
#  |  and/or scoring datasets for a model. A DataDriftDetector object is created with a workspace, a model name
#  |  and version, list of services, and optional tuning parameters. A DataDriftDetector task can be scheduled
#  |  using enable_schedule() API and/or a one time task can be submitted using run() method.
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, workspace, model_name, model_version)
#  |      Datadriftdetector constructor.
#  |
#  |      The DataDriftDetector constructor is used to retrieve a cloud representation of a DataDriftDetector object
# ...
