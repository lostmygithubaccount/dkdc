# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
#
# Licensed under the MIT License.

# %% [markdown]
# ![Impressions](https://PixelServer20190423114238.azurewebsites.net/api/impressions/MachineLearningNotebooks/how-to-use-azureml/work-with-data/datadrift-tutorial/datadrift-quickdemo.png)

# %% [markdown]
# # Analyze data drift in Azure Machine Learning datasets
#
# In this tutorial, you will setup a data drift monitor on a weather dataset to:
#
# &#x2611; Analyze historical data for drift
#
# &#x2611; Setup a monitor to recieve email alerts if data drift is detected going forward
#
# If your workspace is Enterprise level, view and exlpore the results in the Azure Machine Learning studio. The video below shows the results from this tutorial.
#
# ![gif](media/video.gif)

# %% [markdown]
# ## Prerequisites
# If you are using an Azure Machine Learning Compute instance, you are all set. Otherwise, go through the [configuration notebook](../../../configuration.ipynb) if you haven't already established your connection to the AzureML Workspace.

# %%
# Check core SDK version number
import azureml.core

print('SDK version:', azureml.core.VERSION)
# Out:
# SDK version: 1.0.69

# %% [markdown]
# ## Initialize Workspace
#
# Initialize a workspace object from persisted configuration.

# %%
from azureml.core import Workspace

ws = Workspace.from_config()
ws
# Out:
# Workspace.create(name='Azure-ML', subscription_id='60582a10-b9fd-49f1-a546-c4194134bba8', resource_group='copetersRG')

# %% [markdown]
# ## Setup target and baseline datasets
#
# Setup the baseline and target datasets. The baseline will be used to compare each time slice of the target dataset, which is sampled by a given frequency. For further details, see [our documentation](http://aka.ms/datadrift).
#
# The next few cells will:
#   * get the default datastore
#   * upload the `weather-data` to the datastore
#   * create the Tabular dataset from the data
#   * add the timeseries trait by specifying the timestamp column `datetime`
#   * register the dataset
#   * create the baseline as a time slice of the target dataset
#   * optionally, register the baseline dataset
#
# The folder `weather-data` contains weather data from the [NOAA Integrated Surface Data](https://azure.microsoft.com/services/open-datasets/catalog/noaa-integrated-surface-data/) filtered down to to station names containing the string 'FLORIDA' to reduce the size of data. See `get_data.py` to see how this data is curated and modify as desired. This script may take a long time to run, hence the data is provided in the `weather-data` folder for this demo.

# %%
# use default datastore
dstore = ws.get_default_datastore()

# %%
# upload weather data
dstore.upload('weather-data', 'datadrift-data', overwrite=True, show_progress=True)
# Out:
# Uploading an estimated of 118 files
# Uploading weather-data/2010/01/data.parquet
# Uploading weather-data/2010/02/data.parquet
# Uploading weather-data/2010/03/data.parquet
# Uploading weather-data/2010/04/data.parquet
# Uploading weather-data/2010/05/data.parquet
# Uploading weather-data/2010/06/data.parquet
# Uploading weather-data/2010/07/data.parquet
# Uploading weather-data/2010/08/data.parquet
# Uploading weather-data/2010/09/data.parquet
# Uploading weather-data/2010/10/data.parquet
# Uploading weather-data/2010/11/data.parquet
# Uploading weather-data/2010/12/data.parquet
# Uploading weather-data/2011/01/data.parquet
# Uploading weather-data/2011/02/data.parquet
# Uploading weather-data/2011/03/data.parquet
# Uploading weather-data/2011/04/data.parquet
# Uploading weather-data/2011/05/data.parquet
# Uploading weather-data/2011/06/data.parquet
# Uploading weather-data/2011/07/data.parquet
# Uploading weather-data/2011/08/data.parquet
# Uploading weather-data/2011/09/data.parquet
# Uploading weather-data/2011/10/data.parquet
# Uploading weather-data/2011/11/data.parquet
# Uploading weather-data/2011/12/data.parquet
# Uploading weather-data/2012/01/data.parquet
# Uploading weather-data/2012/02/data.parquet
# Uploading weather-data/2012/03/data.parquet
# Uploading weather-data/2012/04/data.parquet
# Uploading weather-data/2012/05/data.parquet
# Uploading weather-data/2012/06/data.parquet
# Uploading weather-data/2012/07/data.parquet
# Uploading weather-data/2012/08/data.parquet
# Uploaded weather-data/2011/02/data.parquet, 1 files out of an estimated total of 118
# Uploaded weather-data/2012/02/data.parquet, 2 files out of an estimated total of 118
# Uploading weather-data/2012/09/data.parquet
# Uploading weather-data/2012/10/data.parquet
# Uploaded weather-data/2010/11/data.parquet, 3 files out of an estimated total of 118
# Uploading weather-data/2012/11/data.parquet
# Uploaded weather-data/2011/03/data.parquet, 4 files out of an estimated total of 118
# Uploading weather-data/2012/12/data.parquet
# Uploaded weather-data/2010/06/data.parquet, 5 files out of an estimated total of 118
# Uploading weather-data/2013/01/data.parquet
# Uploaded weather-data/2012/09/data.parquet, 6 files out of an estimated total of 118
# Uploading weather-data/2013/02/data.parquet
# Uploaded weather-data/2012/10/data.parquet, 7 files out of an estimated total of 118
# Uploading weather-data/2013/03/data.parquet
# Uploaded weather-data/2011/05/data.parquet, 8 files out of an estimated total of 118
# Uploading weather-data/2013/04/data.parquet
# Uploaded weather-data/2010/10/data.parquet, 9 files out of an estimated total of 118
# Uploading weather-data/2013/05/data.parquet
# Uploaded weather-data/2010/03/data.parquet, 10 files out of an estimated total of 118
# Uploading weather-data/2013/06/data.parquet
# Uploaded weather-data/2010/02/data.parquet, 11 files out of an estimated total of 118
# Uploading weather-data/2013/07/data.parquet
# Uploaded weather-data/2010/04/data.parquet, 12 files out of an estimated total of 118
# Uploading weather-data/2013/08/data.parquet
# Uploaded weather-data/2010/12/data.parquet, 13 files out of an estimated total of 118
# Uploading weather-data/2013/09/data.parquet
# Uploaded weather-data/2011/11/data.parquet, 14 files out of an estimated total of 118
# Uploading weather-data/2013/10/data.parquet
# Uploaded weather-data/2011/04/data.parquet, 15 files out of an estimated total of 118
# Uploading weather-data/2013/11/data.parquet
# Uploaded weather-data/2011/12/data.parquet, 16 files out of an estimated total of 118
# Uploading weather-data/2013/12/data.parquet
# Uploaded weather-data/2013/01/data.parquet, 17 files out of an estimated total of 118
# Uploading weather-data/2014/01/data.parquet
# Uploaded weather-data/2011/10/data.parquet, 18 files out of an estimated total of 118
# Uploading weather-data/2014/02/data.parquet
# Uploaded weather-data/2011/06/data.parquet, 19 files out of an estimated total of 118
# Uploading weather-data/2014/03/data.parquet
# Uploaded weather-data/2011/01/data.parquet, 20 files out of an estimated total of 118
# Uploading weather-data/2014/04/data.parquet
# Uploaded weather-data/2010/09/data.parquet, 21 files out of an estimated total of 118
# Uploading weather-data/2014/05/data.parquet
# Uploaded weather-data/2012/11/data.parquet, 22 files out of an estimated total of 118
# Uploading weather-data/2014/06/data.parquet
# Uploaded weather-data/2013/09/data.parquet, 23 files out of an estimated total of 118
# Uploaded weather-data/2010/07/data.parquet, 24 files out of an estimated total of 118
# Uploading weather-data/2014/07/data.parquet
# Uploading weather-data/2014/08/data.parquet
# Uploaded weather-data/2011/07/data.parquet, 25 files out of an estimated total of 118
# Uploading weather-data/2014/09/data.parquet
# Uploaded weather-data/2014/02/data.parquet, 26 files out of an estimated total of 118
# Uploading weather-data/2014/10/data.parquet
# Uploaded weather-data/2012/05/data.parquet, 27 files out of an estimated total of 118
# Uploading weather-data/2014/11/data.parquet
# Uploaded weather-data/2012/07/data.parquet, 28 files out of an estimated total of 118
# Uploading weather-data/2014/12/data.parquet
# Uploaded weather-data/2010/01/data.parquet, 29 files out of an estimated total of 118
# Uploading weather-data/2015/01/data.parquet
# Uploaded weather-data/2011/08/data.parquet, 30 files out of an estimated total of 118
# Uploading weather-data/2015/02/data.parquet
# Uploaded weather-data/2012/04/data.parquet, 31 files out of an estimated total of 118
# Uploading weather-data/2015/03/data.parquet
# Uploaded weather-data/2012/01/data.parquet, 32 files out of an estimated total of 118
# Uploading weather-data/2015/04/data.parquet
# Uploaded weather-data/2012/08/data.parquet, 33 files out of an estimated total of 118
# Uploading weather-data/2015/05/data.parquet
# Uploaded weather-data/2013/03/data.parquet, 34 files out of an estimated total of 118
# Uploading weather-data/2015/06/data.parquet
# Uploaded weather-data/2010/08/data.parquet, 35 files out of an estimated total of 118
# Uploading weather-data/2015/07/data.parquet
# Uploaded weather-data/2014/05/data.parquet, 36 files out of an estimated total of 118
# Uploading weather-data/2015/08/data.parquet
# Uploaded weather-data/2013/10/data.parquet, 37 files out of an estimated total of 118
# Uploading weather-data/2015/09/data.parquet
# Uploaded weather-data/2014/11/data.parquet, 38 files out of an estimated total of 118
# Uploading weather-data/2015/10/data.parquet
# Uploaded weather-data/2014/04/data.parquet, 39 files out of an estimated total of 118
# Uploading weather-data/2015/11/data.parquet
# Uploaded weather-data/2014/06/data.parquet, 40 files out of an estimated total of 118
# Uploading weather-data/2015/12/data.parquet
# Uploaded weather-data/2015/03/data.parquet, 41 files out of an estimated total of 118
# Uploading weather-data/2016/01/data.parquet
# Uploaded weather-data/2015/10/data.parquet, 42 files out of an estimated total of 118
# Uploading weather-data/2016/02/data.parquet
# Uploaded weather-data/2013/11/data.parquet, 43 files out of an estimated total of 118
# Uploading weather-data/2016/03/data.parquet
# Uploaded weather-data/2013/12/data.parquet, 44 files out of an estimated total of 118
# Uploading weather-data/2016/04/data.parquet
# Uploaded weather-data/2015/05/data.parquet, 45 files out of an estimated total of 118
# Uploading weather-data/2016/05/data.parquet
# Uploaded weather-data/2015/07/data.parquet, 46 files out of an estimated total of 118
# Uploading weather-data/2016/06/data.parquet
# Uploaded weather-data/2015/09/data.parquet, 47 files out of an estimated total of 118
# Uploading weather-data/2016/07/data.parquet
# Uploaded weather-data/2014/07/data.parquet, 48 files out of an estimated total of 118
# Uploading weather-data/2016/08/data.parquet
# Uploaded weather-data/2015/11/data.parquet, 49 files out of an estimated total of 118
# Uploading weather-data/2016/09/data.parquet
# Uploaded weather-data/2015/12/data.parquet, 50 files out of an estimated total of 118
# Uploading weather-data/2016/10/data.parquet
# Uploaded weather-data/2015/02/data.parquet, 51 files out of an estimated total of 118
# Uploading weather-data/2016/11/data.parquet
# Uploaded weather-data/2014/12/data.parquet, 52 files out of an estimated total of 118
# Uploading weather-data/2016/12/data.parquet
# Uploaded weather-data/2012/12/data.parquet, 53 files out of an estimated total of 118
# Uploading weather-data/2017/01/data.parquet
# Uploaded weather-data/2015/01/data.parquet, 54 files out of an estimated total of 118
# Uploading weather-data/2017/02/data.parquet
# Uploaded weather-data/2016/02/data.parquet, 55 files out of an estimated total of 118
# Uploading weather-data/2017/03/data.parquet
# Uploaded weather-data/2014/09/data.parquet, 56 files out of an estimated total of 118
# Uploading weather-data/2017/04/data.parquet
# Uploaded weather-data/2015/04/data.parquet, 57 files out of an estimated total of 118
# Uploading weather-data/2017/05/data.parquet
# Uploaded weather-data/2014/10/data.parquet, 58 files out of an estimated total of 118
# Uploading weather-data/2017/06/data.parquet
# Uploaded weather-data/2016/09/data.parquet, 59 files out of an estimated total of 118
# Uploading weather-data/2017/07/data.parquet
# Uploaded weather-data/2014/08/data.parquet, 60 files out of an estimated total of 118
# Uploading weather-data/2017/08/data.parquet
# Uploaded weather-data/2016/01/data.parquet, 61 files out of an estimated total of 118
# Uploading weather-data/2017/09/data.parquet
# Uploaded weather-data/2013/02/data.parquet, 62 files out of an estimated total of 118
# Uploading weather-data/2017/10/data.parquet
# Uploaded weather-data/2014/03/data.parquet, 63 files out of an estimated total of 118
# Uploading weather-data/2017/11/data.parquet
# Uploaded weather-data/2016/10/data.parquet, 64 files out of an estimated total of 118
# Uploading weather-data/2017/12/data.parquet
# Uploaded weather-data/2011/09/data.parquet, 65 files out of an estimated total of 118
# Uploading weather-data/2018/01/data.parquet
# Uploaded weather-data/2015/06/data.parquet, 66 files out of an estimated total of 118
# Uploading weather-data/2018/02/data.parquet
# Uploaded weather-data/2014/01/data.parquet, 67 files out of an estimated total of 118
# Uploading weather-data/2018/03/data.parquet
# Uploaded weather-data/2016/07/data.parquet, 68 files out of an estimated total of 118
# Uploading weather-data/2018/04/data.parquet
# Uploaded weather-data/2015/08/data.parquet, 69 files out of an estimated total of 118
# Uploading weather-data/2018/05/data.parquet
# Uploaded weather-data/2016/03/data.parquet, 70 files out of an estimated total of 118
# Uploading weather-data/2018/06/data.parquet
# Uploaded weather-data/2016/08/data.parquet, 71 files out of an estimated total of 118
# Uploading weather-data/2018/07/data.parquet
# Uploaded weather-data/2013/04/data.parquet, 72 files out of an estimated total of 118
# Uploading weather-data/2018/08/data.parquet
# Uploaded weather-data/2013/08/data.parquet, 73 files out of an estimated total of 118
# Uploading weather-data/2018/09/data.parquet
# Uploaded weather-data/2016/06/data.parquet, 74 files out of an estimated total of 118
# Uploading weather-data/2018/10/data.parquet
# Uploaded weather-data/2012/06/data.parquet, 75 files out of an estimated total of 118
# Uploading weather-data/2018/11/data.parquet
# Uploaded weather-data/2016/04/data.parquet, 76 files out of an estimated total of 118
# Uploading weather-data/2018/12/data.parquet
# Uploaded weather-data/2010/05/data.parquet, 77 files out of an estimated total of 118
# Uploading weather-data/2019/01/data.parquet
# Uploaded weather-data/2017/07/data.parquet, 78 files out of an estimated total of 118
# Uploading weather-data/2019/02/data.parquet
# Uploaded weather-data/2017/02/data.parquet, 79 files out of an estimated total of 118
# Uploading weather-data/2019/03/data.parquet
# Uploaded weather-data/2013/05/data.parquet, 80 files out of an estimated total of 118
# Uploading weather-data/2019/04/data.parquet
# Uploaded weather-data/2017/12/data.parquet, 81 files out of an estimated total of 118
# Uploading weather-data/2019/05/data.parquet
# Uploaded weather-data/2016/05/data.parquet, 82 files out of an estimated total of 118
# Uploading weather-data/2019/06/data.parquet
# Uploaded weather-data/2016/12/data.parquet, 83 files out of an estimated total of 118
# Uploading weather-data/2019/07/data.parquet
# Uploaded weather-data/2017/05/data.parquet, 84 files out of an estimated total of 118
# Uploading weather-data/2019/08/data.parquet
# Uploaded weather-data/2016/11/data.parquet, 85 files out of an estimated total of 118
# Uploading weather-data/2019/09/data.parquet
# Uploaded weather-data/2013/07/data.parquet, 86 files out of an estimated total of 118
# Uploading weather-data/2019/10/data.parquet
# Uploaded weather-data/2018/02/data.parquet, 87 files out of an estimated total of 118
# Uploaded weather-data/2018/04/data.parquet, 88 files out of an estimated total of 118
# Uploaded weather-data/2018/08/data.parquet, 89 files out of an estimated total of 118
# Uploaded weather-data/2018/03/data.parquet, 90 files out of an estimated total of 118
# Uploaded weather-data/2019/02/data.parquet, 91 files out of an estimated total of 118
# Uploaded weather-data/2017/03/data.parquet, 92 files out of an estimated total of 118
# Uploaded weather-data/2019/05/data.parquet, 93 files out of an estimated total of 118
# Uploaded weather-data/2019/03/data.parquet, 94 files out of an estimated total of 118
# Uploaded weather-data/2018/12/data.parquet, 95 files out of an estimated total of 118
# Uploaded weather-data/2019/10/data.parquet, 96 files out of an estimated total of 118
# Uploaded weather-data/2018/01/data.parquet, 97 files out of an estimated total of 118
# Uploaded weather-data/2018/11/data.parquet, 98 files out of an estimated total of 118
# Uploaded weather-data/2019/04/data.parquet, 99 files out of an estimated total of 118
# Uploaded weather-data/2019/06/data.parquet, 100 files out of an estimated total of 118
# Uploaded weather-data/2017/01/data.parquet, 101 files out of an estimated total of 118
# Uploaded weather-data/2017/04/data.parquet, 102 files out of an estimated total of 118
# Uploaded weather-data/2017/08/data.parquet, 103 files out of an estimated total of 118
# Uploaded weather-data/2018/09/data.parquet, 104 files out of an estimated total of 118
# Uploaded weather-data/2019/01/data.parquet, 105 files out of an estimated total of 118
# Uploaded weather-data/2018/05/data.parquet, 106 files out of an estimated total of 118
# Uploaded weather-data/2017/06/data.parquet, 107 files out of an estimated total of 118
# Uploaded weather-data/2018/10/data.parquet, 108 files out of an estimated total of 118
# Uploaded weather-data/2018/06/data.parquet, 109 files out of an estimated total of 118
# Uploaded weather-data/2019/08/data.parquet, 110 files out of an estimated total of 118
# Uploaded weather-data/2017/11/data.parquet, 111 files out of an estimated total of 118
# Uploaded weather-data/2017/10/data.parquet, 112 files out of an estimated total of 118
# Uploaded weather-data/2018/07/data.parquet, 113 files out of an estimated total of 118
# Uploaded weather-data/2019/07/data.parquet, 114 files out of an estimated total of 118
# Uploaded weather-data/2019/09/data.parquet, 115 files out of an estimated total of 118
# Uploaded weather-data/2017/09/data.parquet, 116 files out of an estimated total of 118
# Uploaded weather-data/2013/06/data.parquet, 117 files out of an estimated total of 118
# Uploaded weather-data/2012/03/data.parquet, 118 files out of an estimated total of 118
# Uploaded 118 files
# $AZUREML_DATAREFERENCE_095f2492308546ce8ba51c7f7628ca60

# %%
# import Dataset class
from azureml.core import Dataset

# create target dataset 
target = Dataset.Tabular.from_parquet_files(dstore.path('datadrift-data/**/data.parquet'))
# set the timestamp column
target = target.with_timestamp_columns('datetime')
# register the target dataset
target = target.register(ws, 'target', create_new_version=True)
# retrieve the dataset from the workspace by name
target = Dataset.get_by_name(ws, 'target')

# %%
# import datetime 
from datetime import datetime

# set baseline dataset as January 2019 weather data
baseline = target.time_between(datetime(2010, 1, 1), datetime(2010, 2, 1))

# %%
# optionally, register the baseline dataset. if skipped, an unregistered dataset will be used
#baseline = baseline.register(ws, 'baseline')

# %% [markdown]
# ## Create compute target
#
# Create an Azure Machine Learning compute cluster to run the data drift monitor and associated runs. The below cell will create a compute cluster named `'cpu-cluster'`.

# %%
from azureml.core.compute import AmlCompute, ComputeTarget

compute_name = 'drift-cluster'

if compute_name in ws.compute_targets:
    compute_target = ws.compute_targets[compute_name]
    if compute_target and type(compute_target) is AmlCompute:
        print('found compute target. just use it. ' + compute_name)
else:
    print('creating a new compute target...')
    provisioning_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D4_V2', min_nodes=2, max_nodes=2)

    # create the cluster
    compute_target = ComputeTarget.create(ws, compute_name, provisioning_config)

    # can poll for a minimum number of nodes and for a specific timeout.
    # if no min node count is provided it will use the scale settings for the cluster
    compute_target.wait_for_completion(show_output=True, min_node_count=None, timeout_in_minutes=20)

    # For a more detailed view of current AmlCompute status, use get_status()
    print(compute_target.get_status().serialize())
# Out:
# found compute target. just use it. drift-cluster

# %% [markdown]
# ## Create data drift monitor
#
# See [our documentation](http://aka.ms/datadrift) for a complete description for all of the parameters.

# %%
from azureml.datadrift import DataDriftDetector, AlertConfiguration

alert_config = AlertConfiguration(['cody.peterson@microsoft.com']) # replace with your email to recieve alerts from the scheduled pipeline after enabling

monitor = DataDriftDetector.create_from_datasets(ws, 'cyclical-monitor2', baseline, target, 
                                                      compute_target_name='drift-cluster',  # compute target for scheduled pipeline and backfills 
                                                      frequency='Week',                     # how often to analyze target data
                                                      feature_list=None,                    # list of features to detect drift on
                                                      drift_threshold=None,                 # threshold from 0 to 1 for email alerting
                                                      latency=0,                            # SLA in hours for target data to arrive in the dataset
                                                      alert_config=alert_config)            # email addresses to send alert

# %% [markdown]
# ## Update data drift monitor
#
# Many settings of the data drift monitor can be updated after creation. In this demo, we will update the `drift_threshold` and `feature_list`. See [our documentation](http://aka.ms/datadrift) for details on which settings can be changed.

# %%
# get monitor by name
monitor = DataDriftDetector.get_by_name(ws, 'cyclical-monitor2')

# %%
# create feature list - need to exclude columns that naturally drift or increment over time, such as year, day, index
columns  = list(baseline.take(1).to_pandas_dataframe())
exclude  = ['year', 'day', 'version', '__index_level_0__']
features = [col for col in columns if col not in exclude]

# update the feature list
monitor  = monitor.update(feature_list=features)

# %% [markdown]
# ## Analyze historical data and backfill
#
# You can use the `backfill` method to:
#   * analyze historical data
#   * backfill metrics after updating the settings (mainly the feature list)
#   * backfill metrics for failed runs
#
# The below cells will run two backfills that will produce data drift results for 2019 weather data, with January used as the baseline in the monitor. The output can be seen from the `show` method after the runs have completed, or viewed from the Azure Machine Learning studio for Enterprise workspaces.
#
# ![Drift results](media/drift-results.png)

# %%
for year in range(2010, 2020):
    monitor.backfill(datetime(year, 1, 1), datetime(year, 7, 1))
    monitor.backfill(datetime(year, 7, 1), datetime(year+1, 1, 1))

# %% [markdown]
# >**Tip!** When starting with the data drift capability, start by backfilling on a small section of data to get initial results. Update the feature list as needed by removing columns that are causing drift, but can be ignored, and backfill this section of data until satisfied with the results. Then, backfill on a larger slice of data and/or set the alert configuration, threshold, and enable the schedule to recieve alerts to drift on your dataset. All of this can be done through the UI (Enterprise) or Python SDK.

# %% [markdown]
# Although it depends on many factors, the below backfills should typically take less than 20 minutes to run. Results will show as soon as they become available, not when the backfill is completed, so you may begin to see some metrics in a few minutes.

# %%
# backfill for 1st half of the year
backfill1 = monitor.backfill(datetime(2019, 1, 1), datetime(2019, 7, 1))
backfill1
# Out:
# Run(Experiment: 629823ab-1002-45d7-970d-75bd869f3ba0,
# Id: 629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609,
# Type: azureml.scriptrun,
# Status: Queued)

# %%
# backfill for 2nd half of the year 
backfill2 = monitor.backfill(datetime(2019, 7, 1), datetime(2019, 10, 1))
backfill2
# Out:
# Run(Experiment: 629823ab-1002-45d7-970d-75bd869f3ba0,
# Id: 629823ab-1002-45d7-970d-75bd869f3ba0_1571324158117,
# Type: azureml.scriptrun,
# Status: Queued)

# %% [markdown]
# ## Enable the monitor's pipeline schedule
#
# Turn on a scheduled pipeline which will anlayze the target dataset for drift every `frequency`. Use the latency parameter to adjust the start time of the pipeline. For instance, if it takes 24 hours for my data processing pipelines for data to arrive in the target dataset, set latency to 24.

# %%
# enable the pipeline schedule and recieve email alerts
monitor.enable_schedule()

# %%
# disable the pipeline schedule 
#monitor.disable_schedule()

# %% [markdown]
# ## Query metrics and show results in Python
#
# The below cell will plot some key data drift metrics, and can be used to query the results. Run `help(monitor.get_output)` for specifics on the object returned.

# %%
# make sure the backfills have completed
backfill1.wait_for_completion()
backfill2.wait_for_completion()
# Out:
# WARNING - Retrying (Retry(total=2, connect=2, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8c97b7d0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609
# WARNING - Retrying (Retry(total=1, connect=1, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8c9dcad0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609
# WARNING - Retrying (Retry(total=0, connect=0, read=3, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8c9cb790>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     159             conn = connection.create_connection(
# --> 160                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     161
#
# ~/.local/lib/python3.7/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      56
# ---> 57     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      58         af, socktype, proto, canonname, sa = res
#
# ~/miniconda3/envs/aml/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     602                                                   body=body, headers=headers,
# --> 603                                                   chunked=chunked)
#     604
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     343         try:
# --> 344             self._validate_conn(conn)
#     345         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     842         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 843             conn.connect()
#     844
#
# ~/.local/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     315         # Add certificate verification
# --> 316         conn = self._new_conn()
#     317         hostname = self.host
#
# ~/.local/lib/python3.7/site-packages/urllib3/connection.py in _new_conn(self)
#     168             raise NewConnectionError(
# --> 169                 self, "Failed to establish a new connection: %s" % e)
#     170
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8ca14590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669                                 release_conn=release_conn, body_pos=body_pos,
# --> 670                                 **response_kw)
#     671
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669                                 release_conn=release_conn, body_pos=body_pos,
# --> 670                                 **response_kw)
#     671
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669                                 release_conn=release_conn, body_pos=body_pos,
# --> 670                                 **response_kw)
#     671
#
# ~/.local/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     640             retries = retries.increment(method, url, error=e, _pool=self,
# --> 641                                         _stacktrace=sys.exc_info()[2])
#     642             retries.sleep()
#
# ~/.local/lib/python3.7/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPSConnectionPool(host='southcentralus.experiments.azureml.net', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8ca14590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.local/lib/python3.7/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     141                 request.url,
# --> 142                 **kwargs)
#     143         except requests.RequestException as err:
#
# ~/.local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/.local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~/.local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='southcentralus.experiments.azureml.net', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8ca14590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ClientRequestError                        Traceback (most recent call last)
# <ipython-input-43-f5f0a033c301> in <module>
#       1 # make sure the backfills have completed
# ----> 2 backfill1.wait_for_completion()
#       3 backfill2.wait_for_completion()
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/core/run.py in wait_for_completion(self, show_output, wait_post_processing, raise_on_error)
#     590             while current_status is None or current_status in running_states:
#     591                 time.sleep(1)
# --> 592                 current_status = self.get_status()
#     593
#     594             final_details = self.get_details()
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/core/run.py in get_status(self)
#     852         """
#     853         if self.status not in ["Completed", "Failed", "Canceled"]:
# --> 854             self._client.refresh_run_dto()
#     855         return self.status
#     856
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_run_impl/run_history_facade.py in refresh_run_dto(self)
#     151
#     152     def refresh_run_dto(self):
# --> 153         self.run_dto = self.run.get_run()
#     154
#     155     def get_runstatus(self):
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/run_client.py in get_run(self, **kwargs)
#      67         ExperimentClient, for a specific run_id
#      68         """
# ---> 69         return super(RunClient, self).get_run(self._run_id, **kwargs)
#      70
#      71     def get_token(self):
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/experiment_client.py in get_run(self, run_id, caller, custom_headers, is_async)
#     115
#     116         return self._execute_with_experiment_arguments(
# --> 117             self._client.run.get, run_id=run_id, **kwargs)
#     118
#     119     def get_runs(self, last=0, _filter_on_server=True,
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/experiment_client.py in _execute_with_experiment_arguments(self, func, *args, **kwargs)
#     249
#     250     def _execute_with_experiment_arguments(self, func, *args, **kwargs):
# --> 251         return self._execute_with_arguments(func, copy.deepcopy(self._experiment_arguments), *args, **kwargs)
#     252
#     253     def _combine_with_experiment_paginated_dto(self, func, count_to_download=0, *args, **kwargs):
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/workspace_client.py in _execute_with_arguments(self, func, args_list, *args, **kwargs)
#      80                 return self._call_paginated_api(func, *args_list, **kwargs)
#      81             else:
# ---> 82                 return self._call_api(func, *args_list, **kwargs)
#      83         except ErrorResponseException as e:
#      84             raise ServiceException(e)
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/clientbase.py in _call_api(self, func, *args, **kwargs)
#     219                 return AsyncTask(future, _ident=ident, _parent_logger=self._logger)
#     220             else:
# --> 221                 return self._execute_with_base_arguments(func, *args, **kwargs)
#     222
#     223     def _call_paginated_api(self, func, *args, **kwargs):
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/clientbase.py in _execute_with_base_arguments(self, func, *args, **kwargs)
#     272         total_retry = 0 if self.retries < 0 else self.retries
#     273         return ClientBase._execute_func_internal(
# --> 274             back_off, total_retry, self._logger, func, _noop_reset, *args, **kwargs)
#     275
#     276     @classmethod
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/clientbase.py in _execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     287                 return func(*args, **kwargs)
#     288             except Exception as error:
# --> 289                 left_retry = cls._handle_retry(back_off, left_retry, total_retry, error, logger, func)
#     290
#     291             reset_func(*args, **kwargs)  # reset_func is expected to undo any side effects from a failed func call.
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/clientbase.py in _handle_retry(cls, back_off, left_retry, total_retry, error, logger, func)
#     338                 raise error
#     339         elif not isinstance(error, RETRY_EXCEPTIONS):
# --> 340             raise error
#     341
#     342         delay = back_off * 2 ** (total_retry - left_retry)
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/clientbase.py in _execute_func_internal(cls, back_off, total_retry, logger, func, reset_func, *args, **kwargs)
#     285         while left_retry >= 0:
#     286             try:
# --> 287                 return func(*args, **kwargs)
#     288             except Exception as error:
#     289                 left_retry = cls._handle_retry(back_off, left_retry, total_retry, error, logger, func)
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/_restclient/operations/run_operations.py in get(self, subscription_id, resource_group_name, workspace_name, experiment_name, run_id, custom_headers, raw, **operation_config)
#     297         # Construct and send request
#     298         request = self._client.get(url, query_parameters)
# --> 299         response = self._client.send(request, header_parameters, stream=False, **operation_config)
#     300
#     301         if response.status_code not in [200]:
#
# ~/.local/lib/python3.7/site-packages/msrest/service_client.py in send(self, request, headers, content, **kwargs)
#     334         kwargs.setdefault('stream', True)
#     335         try:
# --> 336             pipeline_response = self.config.pipeline.run(request, **kwargs)
#     337             # There is too much thing that expects this method to return a "requests.Response"
#     338             # to break it in a compatible release.
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/__init__.py in run(self, request, **kwargs)
#     195         pipeline_request = Request(request, context)  # type: Request[HTTPRequestType]
#     196         first_node = self._impl_policies[0] if self._impl_policies else self._sender
# --> 197         return first_node.send(pipeline_request, **kwargs)  # type: ignore
#     198
#     199 class HTTPSender(AbstractContextManager, ABC, Generic[HTTPRequestType, HTTPResponseType]):
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/__init__.py in send(self, request, **kwargs)
#     148         self._policy.on_request(request, **kwargs)
#     149         try:
# --> 150             response = self.next.send(request, **kwargs)
#     151         except Exception:
#     152             if not self._policy.on_exception(request, **kwargs):
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#      70         try:
#      71             try:
# ---> 72                 return self.next.send(request, **kwargs)
#      73             except (oauth2.rfc6749.errors.InvalidGrantError,
#      74                     oauth2.rfc6749.errors.TokenExpiredError) as err:
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#     135
#     136         try:
# --> 137             return self.next.send(request, **kwargs)
#     138         finally:
#     139             if old_max_redirects:
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/__init__.py in send(self, request, **kwargs)
#     148         self._policy.on_request(request, **kwargs)
#     149         try:
# --> 150             response = self.next.send(request, **kwargs)
#     151         except Exception:
#     152             if not self._policy.on_exception(request, **kwargs):
#
# ~/.local/lib/python3.7/site-packages/msrest/pipeline/requests.py in send(self, request, **kwargs)
#     191         return Response(
#     192             request,
# --> 193             self.driver.send(request.http_request, **kwargs)
#     194         )
#
# ~/.local/lib/python3.7/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     331         """
#     332         requests_kwargs = self._configure_send(request, **kwargs)
# --> 333         return super(RequestsHTTPSender, self).send(request, **requests_kwargs)
#     334
#     335
#
# ~/.local/lib/python3.7/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     143         except requests.RequestException as err:
#     144             msg = "Error occurred in request."
# --> 145             raise_with_traceback(ClientRequestError, msg, err)
#     146
#     147         return RequestsClientResponse(request, response)
#
# ~/.local/lib/python3.7/site-packages/msrest/exceptions.py in raise_with_traceback(exception, message, *args, **kwargs)
#      49     error = exception(exc_msg, *args, **kwargs)
#      50     try:
# ---> 51         raise error.with_traceback(exc_traceback)
#      52     except AttributeError:
#      53         error.__traceback__ = exc_traceback
#
# ~/.local/lib/python3.7/site-packages/msrest/universal_http/requests.py in send(self, request, **kwargs)
#     140                 request.method,
#     141                 request.url,
# --> 142                 **kwargs)
#     143         except requests.RequestException as err:
#     144             msg = "Error occurred in request."
#
# ~/.local/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ClientRequestError: Error occurred in request., ConnectionError: HTTPSConnectionPool(host='southcentralus.experiments.azureml.net', port=443): Max retries exceeded with url: /history/v1.0/subscriptions/60582a10-b9fd-49f1-a546-c4194134bba8/resourceGroups/copetersRG/providers/Microsoft.MachineLearningServices/workspaces/Azure-ML/experiments/629823ab-1002-45d7-970d-75bd869f3ba0/runs/629823ab-1002-45d7-970d-75bd869f3ba0_1571324139609 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7ffe8ca14590>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %%
# get results from Python SDK (wait for backfills or monitor runs to finish)
results, metrics = monitor.get_output()

# %%
# plot the results from Python SDK 
monitor.show()

# %% [markdown]
# ## See results in Azure Machine Learning studio (Enterprise only)
#
# The below cell will print a link to the monitor in the Azure Machine Learning studio, where the results can be viewed. Alertnatively, use the `show` or `get_results` to get and plot data drift results in Python.

# %%
link = 'https://ml.azure.com/data/monitor/{}?wsid=/subscriptions/{}/resourcegroups/{}/workspaces/{}'.format(monitor.name, ws.subscription_id, ws.resource_group, ws.name)
print(link)

# %% [markdown]
# ## Delete compute target
#
# Do not delete the compute target if you intend to keep using it for the data drift monitor scheduled runs or otherwise. If the minimum nodes are set to 0, it will scale down soon after jobs are completed, and scale up the next time the cluster is needed.

# %%
# optionally delete the compute target
#compute_target.delete()

# %% [markdown]
# ## Next steps
#
#   * See [our documentation](https://aka.ms/datadrift) or [Python SDK reference](https://docs.microsoft.com/python/api/overview/azure/ml/intro)
#   * [Send requests or feedback](mailto:driftfeedback@microsoft.com) on data drift directly to the team
#   * Please open issues with data drift here on GitHub or on StackOverflow if others are likely to run into the same issue
