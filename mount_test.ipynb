# %%
from azureml.core import Workspace, Dataset

# %%
ws = Workspace.from_config()

# %%
dset = Dataset.get_by_name(ws, 'mnist dataset')

# %%
import tempfile
path = tempfile.mkdtemp()
path
# Out:
# '/tmp/tmpt1cbwf6p'

# %%
dset.mount(path)

# %%
with dset.mount(path):
    import os
    print(os.listdir(path))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-8-98143ec38ddf> in <module>
# ----> 1 with dset.mount(path):
#       2     import os
#       3     print(os.listdir(path))
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/dataprep/fuse/daemon.py in __enter__(self)
#      92             logger.debug('entering MountContext')
#      93             self._mount_using_daemon()
# ---> 94             self._wait_until_mounted()
#      95             self._entered = True
#      96             logger.debug('finished mounting (%s)', self._invocation_id)
#
# ~/miniconda3/envs/aml/lib/python3.7/site-packages/azureml/dataprep/fuse/daemon.py in _wait_until_mounted(self)
#     146         while not os.path.exists(self.mount_point) or not os.path.exists(os.path.join(self.mount_point, SENTINEL_FILE_NAME)):
#     147             if attempt > max_attempt:
# ...
